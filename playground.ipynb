# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df
# Out:
#                           Time    x-force    y-force    z-force
# 0      30/06/2021 11:06:39.640  -2.607060   6.920163  28.038516
# 1      30/06/2021 11:06:39.650  -2.631791   6.946075  28.006557
# 2      30/06/2021 11:06:39.660  -2.589749   6.639634  28.018849
# 3      30/06/2021 11:06:39.670  -2.605205   6.756802  28.053266
# 4      30/06/2021 11:06:39.680  -2.607678   6.994520  28.063100
# ...                        ...        ...        ...        ...
# 91495  30/06/2021 11:21:54.590  10.835990  11.088664 -23.766388
# 91496  30/06/2021 11:21:54.600  10.717282  11.193439 -23.822930
# 91497  30/06/2021 11:21:54.610  10.918838  11.321874 -23.645928
# 91498  30/06/2021 11:21:54.620  10.960262  10.945583 -23.660678
# 91499  30/06/2021 11:21:54.630  10.800748  10.928683 -23.773763
#
# [91500 rows x 4 columns]

# %%
df = pd.read_csv('./data/disc-SMB/skylab_disc-experiment_3_radial_pm_0,2mm.csv')
plt.plot(df['y-force'])

# %%
plt.plot(df['x-force'])

# %%
plt.plot(df['z-force'][:-10000])

# %%
df_sim = pd.read_csv("./data/journal-SMB-simulation/restoring_force.txt",header=7,sep="\s+")
z_sim = np.array(df_sim['r'])
force_sim = np.array(df_sim['Height'])

# %%
plt.plot(z_sim, force_sim)
